# %%
from sqlalchemy import create_engine
import api
db_eng = create_engine('sqlite:///office_raw.db')

# %%
lc = api.loc_code('all')
ym = api.create_ym_list(2006, 2024) 
api.save_all(db_eng, cate = 'office', tab_name = 'office_raw', loc_list = lc, month_list = ym) # 2022부터 다시
# Out:
# 200601 data is saved. 398 locations with no data saved.
# 200602 data is saved. 390 locations with no data saved.
# 200603 data is saved. 377 locations with no data saved.
# 200604 data is saved. 377 locations with no data saved.
# 200605 data is saved. 381 locations with no data saved.
# 200606 data is saved. 385 locations with no data saved.
# 200607 data is saved. 385 locations with no data saved.
# 200608 data is saved. 384 locations with no data saved.
# 200609 data is saved. 381 locations with no data saved.
# 200610 data is saved. 384 locations with no data saved.
# 200611 data is saved. 376 locations with no data saved.
# 200612 data is saved. 378 locations with no data saved.
# 200701 data is saved. 377 locations with no data saved.
# 200702 data is saved. 374 locations with no data saved.
# 200703 data is saved. 376 locations with no data saved.
# 200704 data is saved. 377 locations with no data saved.
# 200705 data is saved. 377 locations with no data saved.
# ...
