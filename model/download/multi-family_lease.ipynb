# %%
import api
eng_apt_lease = api.create_engine('sqlite:////Users/hj/Dropbox/real_estate/data/임대/연립다세대_임대/multi-family_lease.db')

# %%
lc = api.loc_code('all')
ym = api.create_ym_list(2006, 2024) # 2011년 부터 데이터 존재
api.save_all(eng_apt_lease, 'mult-family_lease', 'multi-family_lease', lc, ym)
# Out:
# 200601 data is saved. 257 locations with no data saved.
# 200602 data is saved. 246 locations with no data saved.
# 200603 data is saved. 243 locations with no data saved.
# 200604 data is saved. 238 locations with no data saved.
# 200605 data is saved. 241 locations with no data saved.
# 200606 data is saved. 247 locations with no data saved.
# 200607 data is saved. 240 locations with no data saved.
# 200608 data is saved. 250 locations with no data saved.
# 200609 data is saved. 238 locations with no data saved.
# 200610 data is saved. 245 locations with no data saved.
# 200611 data is saved. 237 locations with no data saved.
# 200612 data is saved. 238 locations with no data saved.
# 200701 data is saved. 242 locations with no data saved.
# 200702 data is saved. 243 locations with no data saved.
# 200703 data is saved. 234 locations with no data saved.
# 200704 data is saved. 241 locations with no data saved.
# 200705 data is saved. 238 locations with no data saved.
# ...
