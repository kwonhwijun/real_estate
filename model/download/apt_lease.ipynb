# %%
import api
eng_apt_lease = api.create_engine('sqlite:////Users/hj/Dropbox/real_estate/data/임대/아파트_임대/apt_lease.db')

# %%
lc = api.loc_code('all')
ym = api.create_ym_list(2017, 2024) # 2011년 부터 데이터 존재
api.save_all(eng_apt_lease, 'apt_lease', 'apt_lease_raw', lc, ym)
# Out:
# 201701 data is saved. 234 locations with no data saved.
# 201702 data is saved. 231 locations with no data saved.
# 201703 data is saved. 237 locations with no data saved.
# 201704 data is saved. 234 locations with no data saved.
# 201705 data is saved. 238 locations with no data saved.
# 201706 data is saved. 237 locations with no data saved.
# 201707 data is saved. 236 locations with no data saved.
# 201708 data is saved. 238 locations with no data saved.
# 201709 data is saved. 240 locations with no data saved.
# 201710 data is saved. 238 locations with no data saved.
# 201711 data is saved. 235 locations with no data saved.
# 201712 data is saved. 237 locations with no data saved.
# 201801 data is saved. 235 locations with no data saved.
# 201802 data is saved. 241 locations with no data saved.
# 201803 data is saved. 237 locations with no data saved.
# 201804 data is saved. 235 locations with no data saved.
# 201805 data is saved. 236 locations with no data saved.
# ...
