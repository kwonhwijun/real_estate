# %%
from sqlalchemy import create_engine
import api
db_eng = create_engine('sqlite:////Users/hj/Dropbox/real_estate/data/db/RealEstate.db')

# %%
lc = api.loc_code('all')
ym = api.create_ym_list(2006, 2024) 
api.save_all(db_eng, cate = 'house', tab_name = 'house_raw', loc_list = lc, month_list = ym)  # 2013년부터 다시
# Out:
# 200601 data is saved. 236 locations with no data saved.
# 200602 data is saved. 228 locations with no data saved.
# 200603 data is saved. 227 locations with no data saved.
# 200604 data is saved. 226 locations with no data saved.
# 200605 data is saved. 226 locations with no data saved.
# 200606 data is saved. 227 locations with no data saved.
# 200607 data is saved. 227 locations with no data saved.
# 200608 data is saved. 227 locations with no data saved.
# 200609 data is saved. 227 locations with no data saved.
# 200610 data is saved. 227 locations with no data saved.
# 200611 data is saved. 226 locations with no data saved.
# 200612 data is saved. 226 locations with no data saved.
# 200701 data is saved. 227 locations with no data saved.
# 200702 data is saved. 226 locations with no data saved.
# 200703 data is saved. 227 locations with no data saved.
# 200704 data is saved. 228 locations with no data saved.
# 200705 data is saved. 226 locations with no data saved.
# ...
